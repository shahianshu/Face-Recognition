# %%
import cv2 as cv
import matplotlib.pyplot as plt

# %%
img=cv.imread('Almighty.JPEG')
newImg=cv.cvtColor(img,cv.COLOR_BGR2RGB) #for converting the default setting of bgr to rgb

# %%
plt.imshow(img)
plt.show()
plt.imshow(newImg)
plt.show()
